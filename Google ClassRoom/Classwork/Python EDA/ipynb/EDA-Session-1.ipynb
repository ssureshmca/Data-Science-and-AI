# %%
############### Packages##########################

************* EDA******************************
1) pandas : Data frame analysis
    
2) numpy  :  Numerical python/Number python [maths]
    
3) Matplotlib : plot 
    
4) seaborn

5) plotly

6) bokhe

*********************** ML packages ***************
7) Scikit-learn (Sklearn)
8) pickle :  save the ML model
9) joblib : save the ML model
    
********************** DL packages****************
10) Tensorflow
11) kears
12) PyTorch


****************** NLP Packages*******************
13) NLTK
14) SciPy

****************** BERT MOdels(Hugging face transformers) *******************
15) Transformers 

******************* GEN AI **********************
16) Chat GPT:   OpenAI + Azure  : Azure packages seperately
17) MakerSuit:  Google          : Google packages
18) Amazon Q :  Amazon           : Aws packages
        
*************** Others***********************
random
math
time
sys
os

# %% [markdown]
# $Step-1:$
#
#
# **Import required packages**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# $Step-2:$
#
#
# **Read the data**

# %% [markdown]
# $visa$-$dataset$

# %%
file_path="C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\Visadataset.csv"

# %%
# <package_name>.<method_name>()
pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $bank$-$dataset$

# %%
file_path1="C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\bank.csv"
pd.read_csv(file_path1,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# $Step-3$
#
# **Create data frames**

# %% [markdown]
# A) Using list

# %%
list1=['Hyd','Mumbai','Benguluru']
list2=['040','022','080']

cols=['City','Code']
city=pd.DataFrame(zip(list1,list2),columns=cols)
# I created a dataframe and I saved in a varaiable city
city
# Out:
#         City Code
# 0        Hyd  040
# 1     Mumbai  022
# 2  Benguluru  080

# %% [markdown]
# B) Save the data in local

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Data science\\Batch-3_Sep28\\EDA-Python'

# %%
city.to_csv('naresh_it_city.csv')

# extra index column created

# %%
city.to_csv('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Data science\\dummy\\naresh_it_city.csv')

# %%
# In file handling we read file in two ways

# python file and data file both are in different location

#              we need to provide the full path

# python file and data file both are in same location
#             we provide only data filename

# %%
city.to_csv('naresh_it_city1.csv',index=False)

# there is no extra index column

# %% [markdown]
# - we create a dataframe using list, data frame name: **city**
#
# - we saved the dataframe in local with index: **naresh_it_city.csv**
#
# - we saved the dataframe in local with out index: **naresh_it_city1.csv**

# %% [markdown]
# $task-1$:
#
# **Read those two dataframes**

# %%
# both python file and data file are at same location
# no need to provide full path location
pd.read_csv('naresh_it_city.csv')
# Out:
#    Unnamed: 0       City  Code
# 0           0        Hyd    40
# 1           1     Mumbai    22
# 2           2  Benguluru    80

# %%
pd.read_csv('naresh_it_city.csv',index_col=0)
# Out:
#         City  Code
# 0        Hyd    40
# 1     Mumbai    22
# 2  Benguluru    80

# %%
pd.read_csv('naresh_it_city1.csv')
# Out:
#         City  Code
# 0        Hyd    40
# 1     Mumbai    22
# 2  Benguluru    80

# %% [markdown]
# C) Change the index

# %%
list1=['Hyd','Mumbai','Benguluru']
list2=['040','022','080']

cols=['City','Code']
city=pd.DataFrame(zip(list1,list2),
                  columns=cols,
                  index=['A','B','C'])
city
# Out:
#         City Code
# A        Hyd  040
# B     Mumbai  022
# C  Benguluru  080

# %% [markdown]
# D) How to add new column

# %%
# what is your dataframe name:city
# what is the new column want to add: Product
# How many rows in your data: 3
# what are the new values for product:['Car','Bus','Train']

# %%
city['Product']=['Car','Bus','Train']

# %%
city
# Out:
#         City Code Product
# A        Hyd  040     Car
# B     Mumbai  022     Bus
# C  Benguluru  080   Train

# %% [markdown]
# E) How to drop the column

# %%
# what is the name of dataframe: City
# Which column you need to drop: Product
# axis =1 ============ > columns
# axis=0 ============== > rows
# You are modifying the table , do you want save the results in same 'city' variable
# or you want to create a new variable

# Suppose I want to keep in same 'City varaible':  inplace=True

city.drop('Product',
          axis=1,
          inplace=True)

# %%
city
# Out:
#         City Code
# A        Hyd  040
# B     Mumbai  022
# C  Benguluru  080

# %% [markdown]
# F) Create a Dataframe using Dictionary

# %%
dict1={'Names':['Ram','Raheem','Robert'],
      'Age':[30,31,32]}

dict1
# Out:
# {'Names': ['Ram', 'Raheem', 'Robert'], 'Age': [30, 31, 32]}

# %%
# keys automatically consider as columns
# values automatically consider as rows
pd.DataFrame(dict1)
# Out:
#     Names  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# **If the values are not in list, then pass the index**

# %%
dict2={'Name':'Naresh_IT',
      'City':'Hyderbad',
      'Age':25}

pd.DataFrame(dict2,
             index=[0,1,2])
# Out:
#         Name      City  Age
# 0  Naresh_IT  Hyderbad   25
# 1  Naresh_IT  Hyderbad   25
# 2  Naresh_IT  Hyderbad   25
